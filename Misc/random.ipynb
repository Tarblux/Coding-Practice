# %%
class Solution:
    def longestPalindrome(self, s: str) -> str:

        def palini(s): 
        
            return s == s[::-1]

            if len(s) <= 1 :
                
                return s 
 
        longest = ''
        
        max_length = 0
            
        for i in range (0,len(s)): 
            
            for j in range (i+1,len(s)):
                
                if s[i] == s[j] : 
                    
                    length = (j - i) + 1
                
                    if palini(s[i:j+1]) == True and length >= max_length : 
                        
                        max_length = length
                        
                        longest = s[i:j+1]
    
        
        return longest if len(longest) > 0 else s[0]

# %%
class Solution:
    
    def palini(self,s): 

            if s == s[::-1] : 

                return True

            else : 

                return False 

    
    def longestPalindrome(self, s: str) -> str:

        if len(s) <= 1 :
            
            return s 
 
        longest = ''
        
        max_length = 0
            
        for i in range (0,len(s)): 
            
            for j in range (i+1,len(s)):
                
                if s[i] == s[j] : 
                    
                    length = (j - i) + 1
                
                    
                    if self.palini(s[i:j+1]) == True and length >= max_length : 
                        
                        max_length = length
                        
                        longest = s[i:j+1]
    
        
        return longest if len(longest) > 0 else s[0]
